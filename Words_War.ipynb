# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulrahmanB-25/Words_War_/blob/main/Words_War.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from english_words import get_english_words_set

# %%
web2lowerset = get_english_words_set(['web2'], lower=True)

# %%
print(len(web2lowerset))
print("computer" in web2lowerset)
print("qwertyuiop" in web2lowerset)
# Out:
# 234450
# True
# False

# %%
class Game():
  def __init__(self,word1,word2):
    self.word1=word1
    self.word2=word2
    self.check_word()
  def check_word(self):
    if len(self.word1) > len(self.word2):
      print("Word 1 is longer than word 2")
    elif len(self.word1) < len(self.word2):
      print("Word 2 is longer than word 1")
    elif len(self.word1) == len(self.word2):
      if self.word1 in web2lowerset and self.word2 in web2lowerset:
        pass
      else:
        print("The words are not in the english dictionary")

    # Check if word is correct english wise and the two words are the same length

  def start_game(self):
    word1_score=0
    word2_score=0
    letters_word1=tuple(self.word1)
    letters_word2=tuple(self.word2)

    for x in range(len(letters_word1)):
      if(ord(letters_word1[x])>ord(letters_word2[x])):
        word1_score = word1_score +1
        print(f"{letters_word1[x],ord(letters_word1[x])} won and {letters_word2[x],ord(letters_word1[x])} lost")
      else:
         word2_score = word2_score +1
         print(f"{letters_word2[x]} won and {letters_word1[x]} lost")


    print("The winner is Word 1") if word1_score> word2_score else print("The winner is Word 2")

    print(f"The first word's score is {word1_score} and the second's word score is {word2_score}")

# %%
    # Need optmizing
    # Need function for matching word
    # Need function for Random word
    # install new dict for explaining  mean of the word
    #install new dict for translation purpose
    # giving the choice to ask the user if he want to play vs bot or pvp




def  AI_OR_pvp():
  pass


game1= Game(input("Enter the first word: "),input("Enter the second word: "))

game1.start_game()
# Out:
# Enter the first word: key
# Enter the second word: key
# k won and k lost
# e won and e lost
# y won and y lost
# The winner is Word 2
# The first word's score is 0 and the second's word score is 3
