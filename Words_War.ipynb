# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulrahmanB-25/Words_War_/blob/main/Words_War.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Word():

  def __init__(self,_word):

    self._word=_word

  def word_length(self):
    return len(self.word)

  def get_letters(self):
    #Returns a tuple of a list of word
    return tuple(self._word)

  def get_word(self):
    return self._word


class Game():
  def __init__(self,word1,word2):
    self.word1=word1
    self.word2=word2


  def check_word(self):
    pass
    # Check if word is correct english wise and the two words are the same length


  def start_game(self):
    word1_score=0
    word2_score=0
    letters_word1=self.word1.get_letters()
    letters_word2=self.word2.get_letters()
    # Need optmizing
    for x in range(len(letters_word1)):
      if(ord(letters_word1[x])>ord(letters_word2[x])):
        word1_score = word1_score +1
        print(f"{letters_word1[x]} won and {letters_word2[x]} lost")
      else:
         word2_score = word2_score +1
         print(f"{letters_word2[x]} won and {letters_word1[x]} lost")


    print("The winner is Word 1") if word1_score> word2_score else print("The winner is Word 2")

    print(f"The first word's score is {word1_score} and the second's word score is {word2_score}")


word11 = Word(input("Enter the first word: "))
word12 = Word(input("Enter the second word: "))



game1= Game(word11,word12)

game1.start_game()
# Out:
# Enter the first word: Meow
# Enter the second word: wows
# w won and M lost
# o won and e lost
# w won and o lost
# w won and s lost
# The winner is Word 2
# The first word's score is 1 and the second's word score is 3
